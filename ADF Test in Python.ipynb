# %%
import pandas as pd

# %%
#to convert the csv file into dataframe
df = pd.read_csv(r"C:\Users\shaky\Downloads\AXISBANK.NS.csv")

# %%
#to view the data 
df
# Out:
#            Date        AXIS
# 0    02-01-2017  447.750000
# 1    03-01-2017  455.250000
# 2    04-01-2017  453.100006
# 3    05-01-2017  458.049988
# 4    06-01-2017  455.200012
# ..          ...         ...
# 243  22-12-2017  553.599976
# 244  26-12-2017  555.000000
# 245  27-12-2017  554.599976
# 246  28-12-2017  546.849976
# 247  29-12-2017  563.950012
#
# [248 rows x 2 columns]

# %%
#importing the plotting lib to show the data in the graph form
import matplotlib.pyplot as plt

# %%
df.AXIS.plot(figsize=(8,4))
plt.show()

# %%
#Now to check the stationarity we will import adf from the stats library

# %%
pip install statsmodels
# Out:
# ...
#                                               0.0/9.2 MB ? eta -:--:--
#                                               0.0/9.2 MB ? eta -:--:--
#                                               0.0/9.2 MB ? eta -:--:--
#                                               0.0/9.2 MB ? eta -:--:--
#                                               0.0/9.2 MB 163.8 kB/s eta 0:00:56
#                                               0.1/9.2 MB 280.5 kB/s eta 0:00:33
#                                               0.1/9.2 MB 280.5 kB/s eta 0:00:33
#                                               0.1/9.2 MB 280.5 kB/s eta 0:00:33
#                                               0.1/9.2 MB 284.4 kB/s eta 0:00:32
#                                               0.2/9.2 MB 419.0 kB/s eta 0:00:22
#                                               0.2/9.2 MB 452.9 kB/s eta 0:00:20
#                                               0.2/9.2 MB 430.1 kB/s eta 0:00:21
# ...

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf = adfuller(df.AXIS, maxlag=1)
adf[0]
# Out:
# -3.1656113673141424

# %%
#Critical values
adf[4]
# Out:
# {'1%': -3.457215237265747,
#  '5%': -2.873361841566324,
#  '10%': -2.5730700760129555}
